# %% [markdown]
# # Import Data

# %%
###import neccessary packages
from lda import guidedlda
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords, wordnet
from nltk.stem.snowball import SnowballStemmer
import pandas as pd
from nltk.stem.porter import *
import os
import docx2txt
import re
import sklearn.feature_extraction
stemmer = PorterStemmer()
newseed_words = pd.read_csv('transcript_seedwords1.csv')
newseed_words = newseed_words.dropna()

###below is the backup old transcript table
text2 = pd.read_csv('Frey transcripts.csv')

# %%
###loads file content into transcript_lists###
transcript_list = []

###file path to locate raw_transcripts folder... make sure file path is correct when running###
directory = '/Users/nicoletang/Desktop/Frey-NLP-Python-Final/Final guidedlda/raw_transcripts'
 
# iterate over files in that directory
for filename in os.listdir(directory):
    my_text = docx2txt.process(directory + '/' + str(filename))
    transcript_list.append(my_text)

# %%
###converts list to dataframe###
text = pd.DataFrame(transcript_list, columns=['raw transcripts'])

# %%
text
# Out:
#                                       raw transcripts
# 0   Bow Knot - BRICK 2.mp4\n\nLindsey: [00:00:03] ...
# 1   On the rocks - Night rain - BRICK 0.mp4\n\nLar...
# 2   9-26 Evening Hanging-out - BRICK.mp4\n\nSpeake...
# 3   Scene 1\n\n\n\nElizabeth: [00:00:12] I ended u...
# 4   Day before Wedding - BRICK 2.mp4\n\nLindsey: [...
# 5   ROER - BRICK 1.mp4\n\nSpeaker1: [00:00:03] I'l...
# 6   Home is a Place for Second Chances- BRICK.mp4\...
# 7   Wedding Day - BRICK 2.mp4\n\nSpeaker1: [00:00:...
# 8   MD Anderson Day BRICK 3.2.mp4\n\nSpeaker1: [00...
# 9   Scene 6\n\n\n\nMaynard: [00:26:28] I noticed w...
# 10  Scene 7\n\n\n\nLars: [00:28:45] Hey, [00:28:30...
# 11  Campfire BRICK.mp4\n\nSpeaker1: [00:00:06] I n...
# 12  Scene 10\n\n\n\nLindsey: [00:36:15] Oh, yeah.\...
# 13  North Carolina BRICK 5.1.mp4\n\nSpeaker1: [00:...
# 14  Scene 11\n\n\n\nLars: [00:41:00] You [00:41:00...
# 15  Scene 8\n\n\n\nLindsey: [00:31:10] I [00:31:00...
# 16  Scene 9\n\n\n\nLindsey: [00:32:51] Probably. J...
# 17  Lindsey Diagnosis - BRICK 2.mp4\n\nSpeaker1: [...
# 18  scene_2.wav\n\n\n\nElizabeth: [00:00:01] This ...
# 19  scene_3.wav\n\n\n\nLindsey: [00:00:03] Before ...
# 20  Water Plant - BRICK 2.mp4\n\nSpeaker1: [00:00:...
# 21  Lindsey & John Intro - BRICK 1.mp4\n\nSpeaker1...
# 22  Deer Kill - BRICK 2 - Glass.mp4\n\nSpeaker1: [...
# 23  Scene 14\n\n\n\nLars: [00:47:43] You [00:47:30...
# 24  Arrival Day BRICK 1.mp4\n\nSpeaker1: [00:00:21...
# 25  Tattoo Tour - BRICK.mp4\n\nSpeaker1: [00:00:02...
# 26  Scene 12\n\n\n\nRyan: [00:44:04] feet [00:44:0...
# 27  Scene 13\n\n\n\nElizabeth: [00:44:53] We are k...
# 28  Scene 5\n\n\n\nElizabeth: [00:21:32] So [00:21...
# 29  Scene 4\n\n\n\nLars: [00:15:35] 35. [00:15:30]...

# %%
text2
# Out:
#     Unnamed: 0                                             tweets  \
# 0            0  Scene 1\n\nElizabeth: [00:00:12] I ended up ha...
# 1            1  scene_2.wav\nElizabeth: [00:00:01] This is my ...
# 2            2  scene_3.wav\nLindsey: [00:00:03] Before I was ...
# 3            4  Scene 4\n\nLars: [00:15:35] 35. [00:15:30]\n\n...
# 4            5  Scene 5\n\nElizabeth: [00:21:32] So [00:21:30]...
# 5            6  Scene 6\n\nMaynard: [00:26:28] I noticed water...
# 6            8  Scene 7\n\nLars: [00:28:45] Hey, [00:28:30] gu...
# 7            9  Scene 8\n\nLindsey: [00:31:10] I [00:31:00] ju...
# 8           10  Scene 9\n\nLindsey: [00:32:51] Probably. Just ...
# 9           11  Scene 10\n\nLindsey: [00:36:15] Oh, yeah.\n\nL...
# 10          12  Scene 11\n\nLars: [00:41:00] You [00:41:00] gu...
# 11          14  Scene 12\n\nRyan: [00:44:04] feet [00:44:00] d...
# 12          15  Scene 13\n\nElizabeth: [00:44:53] We are kind ...
# 13          16  Scene 14\n\nLars: [00:47:43] You [00:47:30] wa...
#
#               date        Company  \
# 0     1/5/21 15:59   transcript 1
# 1   12/30/20 23:14   transcript 2
# 2   12/23/20 19:00   transcript 3
# 3   12/16/20 21:26   transcript 4
# 4   12/15/20 20:16   transcript 5
# 5    12/10/20 0:24   transcript 6
# 6     12/8/20 0:13   transcript 7
# 7    12/5/20 14:13   transcript 8
# 8    12/3/20 23:32   transcript 9
# 9   11/26/20 22:05  transcript 10
# 10  11/24/20 20:57  transcript 11
# 11  11/18/20 22:50  transcript 12
# 12   11/9/20 18:47  transcript 13
# 13  10/30/20 20:16  transcript 14
#
#                                                   url
# 0   https://twitter.com/MemphisMeats/status/134648...
# 1   https://twitter.com/MemphisMeats/status/134442...
# 2   https://twitter.com/MemphisMeats/status/134182...
# 3   https://twitter.com/MemphisMeats/status/133932...
# 4   https://twitter.com/MemphisMeats/status/133894...
# 5   https://twitter.com/MemphisMeats/status/133682...
# 6   https://twitter.com/MemphisMeats/status/133610...
# 7   https://twitter.com/MemphisMeats/status/133522...
# 8   https://twitter.com/MemphisMeats/status/133464...
# 9   https://twitter.com/MemphisMeats/status/133208...
# 10  https://twitter.com/MemphisMeats/status/133134...
# 11  https://twitter.com/MemphisMeats/status/132919...
# 12  https://twitter.com/MemphisMeats/status/132587...
# 13  https://twitter.com/MemphisMeats/status/132227...

# %%
###locates the header of the file content and uses that to name the file###
def head(header):
    actual_header = re.split('\n', header)
    # empty_header.append(actual_header[0])
    return (actual_header[0])

# %%
### creates a new column in the text data frame and loads the filename in correspondence with the raw transcripts###
text['transcript name'] = [head(i) for i in text['raw transcripts']]

# %%
text['transcript name']
# Out:
# 0                            Bow Knot - BRICK 2.mp4
# 1           On the rocks - Night rain - BRICK 0.mp4
# 2              9-26 Evening Hanging-out - BRICK.mp4
# 3                                           Scene 1
# 4                  Day before Wedding - BRICK 2.mp4
# 5                                ROER - BRICK 1.mp4
# 6     Home is a Place for Second Chances- BRICK.mp4
# 7                         Wedding Day - BRICK 2.mp4
# 8                     MD Anderson Day BRICK 3.2.mp4
# 9                                           Scene 6
# 10                                          Scene 7
# 11                               Campfire BRICK.mp4
# 12                                         Scene 10
# 13                     North Carolina BRICK 5.1.mp4
# 14                                         Scene 11
# 15                                          Scene 8
# 16                                          Scene 9
# 17                  Lindsey Diagnosis - BRICK 2.mp4
# 18                                      scene_2.wav
# 19                                      scene_3.wav
# 20                        Water Plant - BRICK 2.mp4
# 21               Lindsey & John Intro - BRICK 1.mp4
# 22                  Deer Kill - BRICK 2 - Glass.mp4
# 23                                         Scene 14
# 24                          Arrival Day BRICK 1.mp4
# 25                          Tattoo Tour - BRICK.mp4
# 26                                         Scene 12
# 27                                         Scene 13
# 28                                          Scene 5
# 29                                          Scene 4
# Name: transcript name, dtype: object

# %%
###dictionary to change numeric values to relevant category###
seedkeys = {'Faith':0, 'Cancer':1, 'Nature':2, 'Mindfullness':3}

# %%
###function that converts numeric value to relevant key. E.g 0 returns 'Faith'###
def get_key(val):
    for key, value in seedkeys.items():
        if val == value:
            return key
 
    return "key doesn't exist"

# %%
###creates dictionary of seed words from seed words csv file e.g Faith: god,hope...###
seed_dict = newseed_words.to_dict('list')

# %%
# seed_dict

# %%
###this section has a function that stems seed words and creates a new stemmed dictionary seed words###
def stemList(l):
    return([stemmer.stem(word) for word in l])

#the following creates a new dictionary where stemming has been applied to the values

stemmed_seed_dict = {}
for key in seed_dict:
    for word in key:
        # print(type(word))
        stemmed_seed_dict[key] = stemList(seed_dict[key])

# %%
seedlist = []

# %%
###creates a final seed words list just like the backup####
for key in stemmed_seed_dict:
    seedlist.append(stemmed_seed_dict[key])
# stemmed_seed_dict['Faith']
seedlist
# Out:
# [['god',
#   'hope',
#   'pray',
#   'believ',
#   'trust',
#   'church',
#   'conviction ',
#   'optim',
#   'religion',
#   'idealog',
#   'confid',
#   'group',
#   'relationship',
#   'mass',
#   'synagogu',
#   'anticip',
#   'futur',
#   'strong',
#   'lord',
#   'read',
#   'wait',
#   'focu',
#   'posit',
#   'plan',
#   'support',
#   'desir',
#   'accept ',
#   'loyal',
#   'truth',
#   'assent',
#   'assur',
#   'constant',
#   'credenc',
#   'credul',
#   'depend',
#   'fealti',
#   'relianc',
#   'sure',
#   'sureti',
#   'troth',
#   'hope',
#   'chang',
#   'brighter',
#   'gratitud',
#   'faith',
#   'opportun',
#   'love',
#   'pray',
#   'hope',
#   'likelihood',
#   'changes to com',
#   'brighter futur'],
#  ['tumor',
#   'radiolog',
#   'chemotherapi',
#   'benign',
#   'inva',
#   'mastectomi',
#   'surgeri',
#   'malign',
#   'metastas',
#   'melanoma',
#   'carcinogen',
#   'cancer',
#   'precanc',
#   'survivor',
#   'diseas',
#   'sick',
#   'ill',
#   'spread',
#   'lump',
#   'cell',
#   'grow',
#   'neck',
#   'bodi',
#   'organ',
#   'lung',
#   'heal',
#   'emerg',
#   'oncologist',
#   'prescript',
#   'm.d.',
#   'test',
#   'pass',
#   'prognosi',
#   'migran',
#   'seizur',
#   'c.t.',
#   'scan',
#   'imag',
#   'heartbeat',
#   'diagnosi',
#   'biopsi',
#   'remov',
#   'carcinoma',
#   'big c',
#   'live',
#   'pass',
#   'radiat',
#   'kidney',
#   'chemo',
#   'passed away',
#   'stage',
#   'kidney canc'],
#  ['earth',
#   'sun',
#   'sky',
#   'star',
#   'tree',
#   'flower',
#   'land',
#   'sea',
#   'ocean',
#   'lake',
#   'river',
#   'rain',
#   'storm',
#   'thunder',
#   'lighten',
#   'snow',
#   'sunset',
#   'sunris',
#   'outsid',
#   'leaf',
#   'trek',
#   'wilder',
#   'anim',
#   'stream',
#   'rock',
#   'bolt',
#   'flood',
#   'weather',
#   'water',
#   'hurrican',
#   'morn',
#   'night',
#   'world',
#   'life',
#   'environ',
#   'landscap',
#   'view',
#   'cosmo',
#   'countri',
#   'forest',
#   'macrocosm',
#   'outdoor',
#   'scenario',
#   'seascap',
#   'electrc',
#   'set',
#   'univers',
#   'natur',
#   'cano',
#   'alaska',
#   'hike',
#   'disast'],
#  ['reflect',
#   'care',
#   'mental health',
#   'introspect',
#   'medit',
#   'center',
#   'concentr',
#   'breath',
#   'relax',
#   'sit',
#   'focu',
#   'yoga',
#   'bodi',
#   'hardship',
#   'redifin',
#   'experi',
#   'sign',
#   'know',
#   'heal',
#   'posit',
#   'mind ',
#   'deep',
#   'bodi',
#   'sens',
#   'tension',
#   'paus',
#   'notic',
#   'heartbeat',
#   'concern',
#   'direct',
#   'forethought',
#   'head',
#   'heed',
#   'interest',
#   'pain',
#   'regard',
#   'sens',
#   'posit',
#   'self-encourag',
#   'feel',
#   'reset',
#   'whole',
#   'chang',
#   'found',
#   'float',
#   'need',
#   'connect',
#   'let go',
#   'welcom',
#   'inspir',
#   'connect',
#   'creat']]

# %%
import csv

with open("seedlist.csv","w+") as my_csv:
    csvWriter = csv.writer(my_csv,delimiter=',')
    csvWriter.writerows(seedlist)

# %%
###!!!!only for old transcript csv files!!!###

# # transcript_seed_words = transcript_seed_words.dropna()
# text2 = text2.dropna()
# text2 = text2.drop(columns="url")
# text2.rename(columns = {'tweets':'transcripts', 'Company':'transcript_name'}, inplace = True)

# %% [markdown]
# # Data Cleaning
# 1. tokenization
# 2. remove @users, hashtag symbols, Urls, and special symbols(i.e., '&amp'), non-alphabetic characters, and words that have less than 3 characters
# 3. remove stopwords
# 4. lowercase transformation
# 5. stemming

# %%
import gensim
import gensim.corpora as corpora
import re
porter = PorterStemmer()
stop_words = stopwords.words('english')
b = []
for i,u in text.iterrows():
    a = []
    word =''
    for words in str(u['raw transcripts']).split(): #tokenization
        if '@' not in words: #remove @users
            words = words.replace('#','') #remove hashtag symbol
            if '#' not in words:
                if 'http' not in words: #remove URLs
                    if'&amp' not in words: #remove symbol
                        words = re.sub(r'[^a-zA-Z]', ' ', words)#remove non-alphabetic characters
                        if len(words)>2:
                            word += (words+' ')
    doc = ''
    for token in word.split():
        if len(token) >2: # remove words that have less than 3 characters
            token = token.lower()# lowercase form
            if token not in stop_words:# remove stopwords
                token = porter.stem(token) #stemming
                doc += (token+' ')
    b.append(doc)
text['processed']=[i for i in b]

# exclude words that are not in English
non_english_list = ['temiz','rkiy','erik','nda','konu','dan','da','ba','al','viand','para','na','dann','uft','laboratorio','dieser','kalbimi',
                   'restoranda','evento','komo','ind','tica','futuro','sonra','yla','cre','ili','daki',
                   'zaman']
index_axis = []
for index,i in text.iterrows():
    if len(i['processed']) == 0:
        index_axis.append(index)
    else:
        for word in i['processed'].split():
            if word in non_english_list:
                index_axis.append(index)
                break
text.drop(text.index[index_axis],inplace=True)
print("number of tweets after cleaning:",len(text))
# Out:
# number of tweets after cleaning: 30

# %%
text
# Out:
#                                       raw transcripts  \
# 0   Bow Knot - BRICK 2.mp4\n\nLindsey: [00:00:03] ...
# 1   On the rocks - Night rain - BRICK 0.mp4\n\nLar...
# 2   9-26 Evening Hanging-out - BRICK.mp4\n\nSpeake...
# 3   Scene 1\n\n\n\nElizabeth: [00:00:12] I ended u...
# 4   Day before Wedding - BRICK 2.mp4\n\nLindsey: [...
# 5   ROER - BRICK 1.mp4\n\nSpeaker1: [00:00:03] I'l...
# 6   Home is a Place for Second Chances- BRICK.mp4\...
# 7   Wedding Day - BRICK 2.mp4\n\nSpeaker1: [00:00:...
# 8   MD Anderson Day BRICK 3.2.mp4\n\nSpeaker1: [00...
# 9   Scene 6\n\n\n\nMaynard: [00:26:28] I noticed w...
# 10  Scene 7\n\n\n\nLars: [00:28:45] Hey, [00:28:30...
# 11  Campfire BRICK.mp4\n\nSpeaker1: [00:00:06] I n...
# 12  Scene 10\n\n\n\nLindsey: [00:36:15] Oh, yeah.\...
# 13  North Carolina BRICK 5.1.mp4\n\nSpeaker1: [00:...
# 14  Scene 11\n\n\n\nLars: [00:41:00] You [00:41:00...
# 15  Scene 8\n\n\n\nLindsey: [00:31:10] I [00:31:00...
# 16  Scene 9\n\n\n\nLindsey: [00:32:51] Probably. J...
# 17  Lindsey Diagnosis - BRICK 2.mp4\n\nSpeaker1: [...
# 18  scene_2.wav\n\n\n\nElizabeth: [00:00:01] This ...
# 19  scene_3.wav\n\n\n\nLindsey: [00:00:03] Before ...
# 20  Water Plant - BRICK 2.mp4\n\nSpeaker1: [00:00:...
# 21  Lindsey & John Intro - BRICK 1.mp4\n\nSpeaker1...
# 22  Deer Kill - BRICK 2 - Glass.mp4\n\nSpeaker1: [...
# 23  Scene 14\n\n\n\nLars: [00:47:43] You [00:47:30...
# 24  Arrival Day BRICK 1.mp4\n\nSpeaker1: [00:00:21...
# 25  Tattoo Tour - BRICK.mp4\n\nSpeaker1: [00:00:02...
# 26  Scene 12\n\n\n\nRyan: [00:44:04] feet [00:44:0...
# 27  Scene 13\n\n\n\nElizabeth: [00:44:53] We are k...
# 28  Scene 5\n\n\n\nElizabeth: [00:21:32] So [00:21...
# 29  Scene 4\n\n\n\nLars: [00:15:35] 35. [00:15:30]...
#
#                                   transcript name  \
# 0                          Bow Knot - BRICK 2.mp4
# 1         On the rocks - Night rain - BRICK 0.mp4
# 2            9-26 Evening Hanging-out - BRICK.mp4
# 3                                         Scene 1
# 4                Day before Wedding - BRICK 2.mp4
# 5                              ROER - BRICK 1.mp4
# 6   Home is a Place for Second Chances- BRICK.mp4
# 7                       Wedding Day - BRICK 2.mp4
# 8                   MD Anderson Day BRICK 3.2.mp4
# 9                                         Scene 6
# 10                                        Scene 7
# 11                             Campfire BRICK.mp4
# 12                                       Scene 10
# 13                   North Carolina BRICK 5.1.mp4
# 14                                       Scene 11
# 15                                        Scene 8
# 16                                        Scene 9
# 17                Lindsey Diagnosis - BRICK 2.mp4
# 18                                    scene_2.wav
# 19                                    scene_3.wav
# 20                      Water Plant - BRICK 2.mp4
# 21             Lindsey & John Intro - BRICK 1.mp4
# 22                Deer Kill - BRICK 2 - Glass.mp4
# 23                                       Scene 14
# 24                        Arrival Day BRICK 1.mp4
# 25                        Tattoo Tour - BRICK.mp4
# 26                                       Scene 12
# 27                                       Scene 13
# 28                                        Scene 5
# 29                                        Scene 4
#
#                                             processed
# 0   bow knot brick lindsey readi order custom gues...
# 1   rock night rain brick lar tnt guid hey guy goo...
# 2   even hang brick speaker got bean pepper onion ...
# 3   scene elizabeth end nine hour surgeri two mont...
# 4   day wed brick lindsey second ryan yeah lindsey...
# 5   roer brick speaker check radar go storm come a...
# 6   home place second chanc brick speaker big one ...
# 7   wed day brick speaker ye sun shine bright good...
# 8   anderson day brick speaker hear thunder awesom...
# 9   scene maynard notic water reflect light onto s...
# 10  scene lar hey guy good job welcom camp right r...
# 11  campfir brick speaker notic water reflect ligh...
# 12  scene lindsey yeah lindsey went trip septemb s...
# 13  north carolina brick speaker buck get one even...
# 14  scene lar guy turn well oil machin move river ...
# 15  scene lindsey see make feel big yet small roy ...
# 16  scene lindsey probabl tri build fire get done ...
# 17  lindsey diagnosi brick speaker alway mother do...
# 18  scene wav elizabeth case run realli fast away ...
# 19  scene wav lindsey diagnos still colleg found t...
# 20  water plant brick speaker water line buri righ...
# 21  lindsey john intro brick speaker first move ho...
# 22  deer kill brick glass speaker mom bathroom hug...
# 23  scene lar want park boat boat littl muddi lind...
# 24  arriv day brick speaker baton entranc take tic...
# 25  tattoo tour brick speaker tattoo got mastectom...
# 26  scene ryan feet get cold lindsey feet got hot ...
# 27  scene elizabeth kind settl fact limit option s...
# 28  scene elizabeth saw hematologist oncologist fi...
# 29  scene lar lar know bag everyth yeah yeah one t...

# %% [markdown]
# # GuidedLDA Model
# latent topics are identified from the bigrams shown above.

# %%
#back up seed words
seed_words = [['god','hope','pray','believ','trust','church','convict','optim','religion','ideaolog','confid','group','relationship',
      'mass','synagogu','anticip','futur','strong','lord','readi','wait','focu','posit','plan','support',
      'desir','accept','loyal','truth','assent','assur','constant','credenc','credul','depend','fealti',
        'relianc','sure','sureti','troth', 
        'hope', 'chang', 'brighter','gratitud','faith', 'opportun', 'love', 'pray', 'hope', 'likelihood'],#0 Faith
      ['tumor','radiolog','chemotherapi','benign','invas','mastectomi','surgeri','malign','metastasi','melanoma',
       'carcigen','cancer','precancer','survivor','diseas','sick','ill','spread','lump','cell','grow','neck','bodi',
       'organ','lung','heal','emerg','oncologist','prescript','m.d.','test','pass','prognosi','migran','seizur','c.t.',
       'scan','imag','heartbeat','diagnosi','biopsi','remov','carcinoma','big c', 'live', 
       'pass', 'radiat', 'kidney', 'chemo'],#1 Cancer
      ['earth','sun','sky','star','tree','flower','land','sea','ocean','lake','river','rain','storm','thunder',
       'lighten','snow','sunset','sunris','outsid','leaf','trek','wilder','anim','stream','rock','bolt','flood',
       'weather','water','hurrican','morn','night','world','life','environ','landscap','view','cosmo','countri','forest',
       'macrocosm','outdoor','sceneri','seascap','electr',
       'set','univers','natur', 'cano', 'alaska', 'hike', 'disast', 'float',  
       'forest', 'fire', 'soil', 'canyon', 'butterfli', 'camp', 
       'gear', 'flower', 'mountain', 'hike', 'paddl', 'sunris', 'boat', 'backcountri'],#2 Nature
      ['reflect','care','self car','health','consider','conscienti','regard','thought','thougt','well',
       'well-b','feel','mental health','introspect','meditat','center','concentr','breath','relax','sit','focu',
       'yoga','bodi','hardship','redifin','experi','sign','know','heal',
       'posit','mind','deep','bodi','sens','tension','paus','notic','heartbeat',
       'heart','check','self-esteem','confid','alert','care',
       'concern','direct','forethougt',
       'head','heed','interest','pain','regard',
      'sens','breath','bodi','notic','posit','self-encourag','feel','reset','whole','chang',
       'found','float','need','connect','let go','welcom','inspir','connect','creat','feast',
       'feel','coma']]#3 Mindfullness

# %%
import csv

with open("seed_words.csv","w+") as my_csv:
    csvWriter = csv.writer(my_csv,delimiter=',')
    csvWriter.writerows(seed_words)

# %%
####actual guided topic model function and list of vocabulary from the transcripts###

from sklearn.feature_extraction.text import CountVectorizer
from lda import guidedlda as guidedlda
import numpy as np
model = guidedlda.GuidedLDA(n_topics=4,n_iter=1000,random_state=2022,refresh=10,alpha=0.01,eta=0.01) #alpha=0.01,eta=0.01

vectorizer = CountVectorizer(ngram_range=(1,2))
X = vectorizer.fit_transform(text['processed'])

stemmed_missing =[]#list of words not found in the vocabulary
vocab = vectorizer.get_feature_names()
procab = vectorizer.get_feature_names()
word2id = dict((v,idx) for idx,v in enumerate(vocab))
seed_topics = {}

###connects words from the seed words list to the words in the vocabulary under one numeric I.D ###

for t_id, st in enumerate(seedlist):
    for word in st:
        try:
            seed_topics[word2id[word]] = t_id
        except:
            stemmed_missing.append(word)#adds words not found in vocab into stemmed_missing list
            print(word," skipped")

model.fit(X.toarray(),seed_topics=seedlist,seed_confidence=0.1) #set seed confidence to 0.8
topic_word = model.topic_word_
n_top_words = 20
vocab = tuple(vocab)

for i, topic_dist in enumerate(topic_word): #Print out results
    print('\n')
    print('Topic:',i)
    words_probability = np.array(-topic_dist)
    for index in range(n_top_words):
        print(round(abs(np.sort(words_probability))[:(n_top_words)][index],4),'*',
              np.array(vocab)[np.argsort(topic_dist)][:-(n_top_words+1):-1][index],sep='',end='  ')
# Out:
# /Users/nicoletang/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# INFO:guidedlda:n_documents: 30
# INFO:guidedlda:vocab_size: 7337
# INFO:guidedlda:n_words: 15336
# INFO:guidedlda:n_topics: 4
# INFO:guidedlda:n_iter: 1000
# church  skipped
# conviction   skipped
# optim  skipped
# idealog  skipped
# mass  skipped
# synagogu  skipped
# accept   skipped
# loyal  skipped
# truth  skipped
# assent  skipped
# assur  skipped
# credenc  skipped
# credul  skipped
# depend  skipped
# fealti  skipped
# relianc  skipped
# sureti  skipped
# troth  skipped
# changes to com  skipped
# radiolog  skipped
# benign  skipped
# inva  skipped
# malign  skipped
# melanoma  skipped
# carcinogen  skipped
# precanc  skipped
# survivor  skipped
# diseas  skipped
# ill  skipped
# lump  skipped
# cell  skipped
# m.d.  skipped
# migran  skipped
# c.t.  skipped
# carcinoma  skipped
# big c  skipped
# passed away  skipped
# kidney canc  skipped
# sky  skipped
# sea  skipped
# lake  skipped
# lighten  skipped
# snow  skipped
# sunset  skipped
# leaf  skipped
# trek  skipped
# wilder  skipped
# stream  skipped
# bolt  skipped
# environ  skipped
# landscap  skipped
# view  skipped
# cosmo  skipped
# macrocosm  skipped
# scenario  skipped
# seascap  skipped
# electrc  skipped
# univers  skipped
# mental health  skipped
# introspect  skipped
# medit  skipped
# concentr  skipped
# redifin  skipped
# mind   skipped
# direct  skipped
# forethought  skipped
# heed  skipped
# interest  skipped
# regard  skipped
# self-encourag  skipped
# let go  skipped
# /Users/nicoletang/opt/anaconda3/lib/python3.9/site-packages/lda/guidedlda.py:301: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if w not in seed_topics:
# /Users/nicoletang/opt/anaconda3/lib/python3.9/site-packages/lda/guidedlda.py:316: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if w in seed_topics:
# INFO:guidedlda:<0> log likelihood: -176119
# INFO:guidedlda:<10> log likelihood: -156472
# INFO:guidedlda:<20> log likelihood: -155179
# INFO:guidedlda:<30> log likelihood: -154603
# INFO:guidedlda:<40> log likelihood: -154110
# INFO:guidedlda:<50> log likelihood: -153412
# INFO:guidedlda:<60> log likelihood: -152696
# INFO:guidedlda:<70> log likelihood: -152296
# INFO:guidedlda:<80> log likelihood: -151947
# INFO:guidedlda:<90> log likelihood: -151535
# INFO:guidedlda:<100> log likelihood: -151298
# INFO:guidedlda:<110> log likelihood: -151187
# INFO:guidedlda:<120> log likelihood: -151087
# INFO:guidedlda:<130> log likelihood: -150862
# INFO:guidedlda:<140> log likelihood: -150828
# INFO:guidedlda:<150> log likelihood: -150874
# INFO:guidedlda:<160> log likelihood: -150742
# INFO:guidedlda:<170> log likelihood: -150479
# INFO:guidedlda:<180> log likelihood: -150587
# INFO:guidedlda:<190> log likelihood: -150433
# INFO:guidedlda:<200> log likelihood: -150338
# INFO:guidedlda:<210> log likelihood: -150233
# INFO:guidedlda:<220> log likelihood: -150268
# INFO:guidedlda:<230> log likelihood: -150295
# INFO:guidedlda:<240> log likelihood: -150114
# INFO:guidedlda:<250> log likelihood: -150215
# INFO:guidedlda:<260> log likelihood: -150142
# INFO:guidedlda:<270> log likelihood: -150026
# INFO:guidedlda:<280> log likelihood: -150286
# INFO:guidedlda:<290> log likelihood: -150015
# INFO:guidedlda:<300> log likelihood: -150032
# INFO:guidedlda:<310> log likelihood: -150057
# INFO:guidedlda:<320> log likelihood: -150064
# INFO:guidedlda:<330> log likelihood: -149860
# INFO:guidedlda:<340> log likelihood: -149867
# INFO:guidedlda:<350> log likelihood: -149974
# INFO:guidedlda:<360> log likelihood: -149869
# INFO:guidedlda:<370> log likelihood: -149959
# INFO:guidedlda:<380> log likelihood: -149960
# INFO:guidedlda:<390> log likelihood: -150035
# INFO:guidedlda:<400> log likelihood: -149859
# INFO:guidedlda:<410> log likelihood: -149959
# INFO:guidedlda:<420> log likelihood: -149872
# INFO:guidedlda:<430> log likelihood: -149759
# INFO:guidedlda:<440> log likelihood: -149905
# INFO:guidedlda:<450> log likelihood: -149977
# INFO:guidedlda:<460> log likelihood: -149985
# INFO:guidedlda:<470> log likelihood: -149785
# INFO:guidedlda:<480> log likelihood: -149648
# INFO:guidedlda:<490> log likelihood: -149714
# INFO:guidedlda:<500> log likelihood: -149848
# INFO:guidedlda:<510> log likelihood: -149840
# INFO:guidedlda:<520> log likelihood: -149812
# INFO:guidedlda:<530> log likelihood: -149701
# INFO:guidedlda:<540> log likelihood: -149719
# INFO:guidedlda:<550> log likelihood: -149597
# INFO:guidedlda:<560> log likelihood: -149718
# INFO:guidedlda:<570> log likelihood: -149637
# INFO:guidedlda:<580> log likelihood: -149649
# INFO:guidedlda:<590> log likelihood: -149551
# INFO:guidedlda:<600> log likelihood: -149658
# INFO:guidedlda:<610> log likelihood: -149667
# INFO:guidedlda:<620> log likelihood: -149504
# INFO:guidedlda:<630> log likelihood: -149646
# INFO:guidedlda:<640> log likelihood: -149575
# INFO:guidedlda:<650> log likelihood: -149494
# INFO:guidedlda:<660> log likelihood: -149464
# INFO:guidedlda:<670> log likelihood: -149525
# INFO:guidedlda:<680> log likelihood: -149516
# INFO:guidedlda:<690> log likelihood: -149739
# INFO:guidedlda:<700> log likelihood: -149565
# INFO:guidedlda:<710> log likelihood: -149810
# INFO:guidedlda:<720> log likelihood: -149649
# INFO:guidedlda:<730> log likelihood: -149870
# INFO:guidedlda:<740> log likelihood: -149760
# INFO:guidedlda:<750> log likelihood: -149895
# INFO:guidedlda:<760> log likelihood: -149969
# INFO:guidedlda:<770> log likelihood: -150200
# INFO:guidedlda:<780> log likelihood: -149744
# INFO:guidedlda:<790> log likelihood: -149636
# INFO:guidedlda:<800> log likelihood: -149635
# INFO:guidedlda:<810> log likelihood: -149668
# INFO:guidedlda:<820> log likelihood: -149654
# INFO:guidedlda:<830> log likelihood: -149811
# INFO:guidedlda:<840> log likelihood: -149574
# INFO:guidedlda:<850> log likelihood: -149595
# INFO:guidedlda:<860> log likelihood: -149570
# INFO:guidedlda:<870> log likelihood: -149728
# INFO:guidedlda:<880> log likelihood: -149662
# INFO:guidedlda:<890> log likelihood: -149675
# INFO:guidedlda:<900> log likelihood: -149782
# INFO:guidedlda:<910> log likelihood: -149720
# INFO:guidedlda:<920> log likelihood: -149791
# INFO:guidedlda:<930> log likelihood: -149973
# INFO:guidedlda:<940> log likelihood: -149702
# INFO:guidedlda:<950> log likelihood: -149669
# INFO:guidedlda:<960> log likelihood: -149761
# INFO:guidedlda:<970> log likelihood: -149751
# INFO:guidedlda:<980> log likelihood: -149768
# INFO:guidedlda:<990> log likelihood: -149573
# INFO:guidedlda:<999> log likelihood: -149520
# Topic: 0
# 0.0558*speaker  0.0107*go  0.0096*know  0.0087*time  0.0059*fuck  0.0054*day  0.0045*cancer  0.0045*thing  0.0039*old  0.0039*told  0.0034*make  0.0034*lindsay  0.0034*well  0.0031*guy  0.0031*turn  0.0031*okay  0.0031*year old  0.0031*fish  0.0031*need  0.0028*move
#
# Topic: 1
# 0.0245*lindsey  0.0151*right  0.0085*guid  0.008*go  0.008*dad  0.0069*good  0.0069*roy  0.0066*ryan  0.0061*give  0.0058*phil  0.0055*okay  0.0052*lindsey dad  0.005*never  0.005*john  0.005*love  0.0047*guy  0.0047*time  0.0047*heart  0.0047*let  0.0047*mirror
#
# Topic: 2
# 0.0257*like  0.0167*get  0.0164*one  0.016*yeah  0.0147*speaker  0.0125*realli  0.0108*got  0.0105*come  0.0105*right  0.0099*see  0.009*think  0.0086*would  0.0083*back  0.0074*year  0.0072*littl  0.0064*water  0.0057*start  0.0057*peopl  0.0057*want  0.0053*someth
#
# Topic: 3
# 0.0103*elizabeth  0.0093*know  0.0067*kid  0.0063*breath  0.0063*day  0.0057*away  0.0057*kind  0.0043*take  0.0043*wait  0.004*feel  0.004*want  0.0037*actual  0.0037*sinc  0.0037*thing  0.0037*justin  0.0037*part  0.0033*let  0.0033*go  0.003*need  0.003*home

# %%
vocab
with open("vocab.txt", 'w+') as fp:
    fp.write('\n'.join(vocab))

# %% [markdown]
# # Company-Topic Heatmap
# Based on proportion of each topic for each company

# %%
###this section creates the columns "topic number" and "category" in the data frame and loads the neccessary information

doc_topic = model.transform(X)
topic_number1 = []#list of topic numbers for each transcript in order

###connects relevant topic number and category to respective transcript name###

for i in range(len(doc_topic)):
    topic_number1.append(doc_topic[i].argmax())
text['topic number'] = [i for i in topic_number1]
text['category'] = [get_key(i) for i in text['topic number']]
text
# Out:
#                                       raw transcripts  \
# 0   Bow Knot - BRICK 2.mp4\n\nLindsey: [00:00:03] ...
# 1   On the rocks - Night rain - BRICK 0.mp4\n\nLar...
# 2   9-26 Evening Hanging-out - BRICK.mp4\n\nSpeake...
# 3   Scene 1\n\n\n\nElizabeth: [00:00:12] I ended u...
# 4   Day before Wedding - BRICK 2.mp4\n\nLindsey: [...
# 5   ROER - BRICK 1.mp4\n\nSpeaker1: [00:00:03] I'l...
# 6   Home is a Place for Second Chances- BRICK.mp4\...
# 7   Wedding Day - BRICK 2.mp4\n\nSpeaker1: [00:00:...
# 8   MD Anderson Day BRICK 3.2.mp4\n\nSpeaker1: [00...
# 9   Scene 6\n\n\n\nMaynard: [00:26:28] I noticed w...
# 10  Scene 7\n\n\n\nLars: [00:28:45] Hey, [00:28:30...
# 11  Campfire BRICK.mp4\n\nSpeaker1: [00:00:06] I n...
# 12  Scene 10\n\n\n\nLindsey: [00:36:15] Oh, yeah.\...
# 13  North Carolina BRICK 5.1.mp4\n\nSpeaker1: [00:...
# 14  Scene 11\n\n\n\nLars: [00:41:00] You [00:41:00...
# 15  Scene 8\n\n\n\nLindsey: [00:31:10] I [00:31:00...
# 16  Scene 9\n\n\n\nLindsey: [00:32:51] Probably. J...
# 17  Lindsey Diagnosis - BRICK 2.mp4\n\nSpeaker1: [...
# 18  scene_2.wav\n\n\n\nElizabeth: [00:00:01] This ...
# 19  scene_3.wav\n\n\n\nLindsey: [00:00:03] Before ...
# 20  Water Plant - BRICK 2.mp4\n\nSpeaker1: [00:00:...
# 21  Lindsey & John Intro - BRICK 1.mp4\n\nSpeaker1...
# 22  Deer Kill - BRICK 2 - Glass.mp4\n\nSpeaker1: [...
# 23  Scene 14\n\n\n\nLars: [00:47:43] You [00:47:30...
# 24  Arrival Day BRICK 1.mp4\n\nSpeaker1: [00:00:21...
# 25  Tattoo Tour - BRICK.mp4\n\nSpeaker1: [00:00:02...
# 26  Scene 12\n\n\n\nRyan: [00:44:04] feet [00:44:0...
# 27  Scene 13\n\n\n\nElizabeth: [00:44:53] We are k...
# 28  Scene 5\n\n\n\nElizabeth: [00:21:32] So [00:21...
# 29  Scene 4\n\n\n\nLars: [00:15:35] 35. [00:15:30]...
#
#                                   transcript name  \
# 0                          Bow Knot - BRICK 2.mp4
# 1         On the rocks - Night rain - BRICK 0.mp4
# 2            9-26 Evening Hanging-out - BRICK.mp4
# 3                                         Scene 1
# 4                Day before Wedding - BRICK 2.mp4
# 5                              ROER - BRICK 1.mp4
# 6   Home is a Place for Second Chances- BRICK.mp4
# 7                       Wedding Day - BRICK 2.mp4
# 8                   MD Anderson Day BRICK 3.2.mp4
# 9                                         Scene 6
# 10                                        Scene 7
# 11                             Campfire BRICK.mp4
# 12                                       Scene 10
# 13                   North Carolina BRICK 5.1.mp4
# 14                                       Scene 11
# 15                                        Scene 8
# 16                                        Scene 9
# 17                Lindsey Diagnosis - BRICK 2.mp4
# 18                                    scene_2.wav
# 19                                    scene_3.wav
# 20                      Water Plant - BRICK 2.mp4
# 21             Lindsey & John Intro - BRICK 1.mp4
# 22                Deer Kill - BRICK 2 - Glass.mp4
# 23                                       Scene 14
# 24                        Arrival Day BRICK 1.mp4
# 25                        Tattoo Tour - BRICK.mp4
# 26                                       Scene 12
# 27                                       Scene 13
# 28                                        Scene 5
# 29                                        Scene 4
#
#                                             processed  topic number  \
# 0   bow knot brick lindsey readi order custom gues...             1
# 1   rock night rain brick lar tnt guid hey guy goo...             1
# 2   even hang brick speaker got bean pepper onion ...             2
# 3   scene elizabeth end nine hour surgeri two mont...             3
# 4   day wed brick lindsey second ryan yeah lindsey...             1
# 5   roer brick speaker check radar go storm come a...             2
# 6   home place second chanc brick speaker big one ...             0
# 7   wed day brick speaker ye sun shine bright good...             0
# 8   anderson day brick speaker hear thunder awesom...             3
# 9   scene maynard notic water reflect light onto s...             2
# 10  scene lar hey guy good job welcom camp right r...             1
# 11  campfir brick speaker notic water reflect ligh...             2
# 12  scene lindsey yeah lindsey went trip septemb s...             1
# 13  north carolina brick speaker buck get one even...             0
# 14  scene lar guy turn well oil machin move river ...             0
# 15  scene lindsey see make feel big yet small roy ...             1
# 16  scene lindsey probabl tri build fire get done ...             1
# 17  lindsey diagnosi brick speaker alway mother do...             0
# 18  scene wav elizabeth case run realli fast away ...             3
# 19  scene wav lindsey diagnos still colleg found t...             0
# 20  water plant brick speaker water line buri righ...             3
# 21  lindsey john intro brick speaker first move ho...             0
# 22  deer kill brick glass speaker mom bathroom hug...             1
# 23  scene lar want park boat boat littl muddi lind...             1
# 24  arriv day brick speaker baton entranc take tic...             0
# 25  tattoo tour brick speaker tattoo got mastectom...             2
# 26  scene ryan feet get cold lindsey feet got hot ...             1
# 27  scene elizabeth kind settl fact limit option s...             3
# 28  scene elizabeth saw hematologist oncologist fi...             3
# 29  scene lar lar know bag everyth yeah yeah one t...             0
#
#         category
# 0         Cancer
# 1         Cancer
# 2         Nature
# 3   Mindfullness
# 4         Cancer
# 5         Nature
# 6          Faith
# 7          Faith
# 8   Mindfullness
# 9         Nature
# 10        Cancer
# 11        Nature
# 12        Cancer
# 13         Faith
# 14         Faith
# 15        Cancer
# 16        Cancer
# 17         Faith
# 18  Mindfullness
# 19         Faith
# 20  Mindfullness
# 21         Faith
# 22        Cancer
# 23        Cancer
# 24         Faith
# 25        Nature
# 26        Cancer
# 27  Mindfullness
# 28  Mindfullness
# 29         Faith

# %%
###groups results by 'transcript name' and  'category'###
results = text[['transcript name', 'category']]

# %%
results
# Out:
#                                   transcript name      category
# 0                          Bow Knot - BRICK 2.mp4        Cancer
# 1         On the rocks - Night rain - BRICK 0.mp4        Cancer
# 2            9-26 Evening Hanging-out - BRICK.mp4        Nature
# 3                                         Scene 1  Mindfullness
# 4                Day before Wedding - BRICK 2.mp4        Cancer
# 5                              ROER - BRICK 1.mp4        Nature
# 6   Home is a Place for Second Chances- BRICK.mp4         Faith
# 7                       Wedding Day - BRICK 2.mp4         Faith
# 8                   MD Anderson Day BRICK 3.2.mp4  Mindfullness
# 9                                         Scene 6        Nature
# 10                                        Scene 7        Cancer
# 11                             Campfire BRICK.mp4        Nature
# 12                                       Scene 10        Cancer
# 13                   North Carolina BRICK 5.1.mp4         Faith
# 14                                       Scene 11         Faith
# 15                                        Scene 8        Cancer
# 16                                        Scene 9        Cancer
# 17                Lindsey Diagnosis - BRICK 2.mp4         Faith
# 18                                    scene_2.wav  Mindfullness
# 19                                    scene_3.wav         Faith
# 20                      Water Plant - BRICK 2.mp4  Mindfullness
# 21             Lindsey & John Intro - BRICK 1.mp4         Faith
# 22                Deer Kill - BRICK 2 - Glass.mp4        Cancer
# 23                                       Scene 14        Cancer
# 24                        Arrival Day BRICK 1.mp4         Faith
# 25                        Tattoo Tour - BRICK.mp4        Nature
# 26                                       Scene 12        Cancer
# 27                                       Scene 13  Mindfullness
# 28                                        Scene 5  Mindfullness
# 29                                        Scene 4         Faith

# %%
#####################################################################
#this section allows you to perform three main goals: 
#1) retrive transcripts based on genre 
#2) retrive transcripts based on transcript
#3) retrieve table results

# %%
###this function returns the transcripts for the input category (case sensitive!)###

def get_genre_scripts():
    category = input()
    #print(category)
    return(text['transcript name'][text['category'] == str(category)].values)

# %%
#get_genre_scripts()

# %%
###this function returns the category for the input transcript (case sensitive!)###

def get_script_genre():
    print('enter transcript name exactly as saved in file')
    transcriptinput = input()
    return(text['category'][text['transcript name'] == str(transcriptinput)].values)

# %%
#get_script_genre()

# %%
# get_script_genre('transcript 5')

# %%
##this function prompts you to search for results based on transcript or category###

def search():
    print('enter transcripts or category to pick your search method')
    method = input()
    if method in text['transcript name']:
        #get_script_genre()
        #return(text['category'][text['transcript name'] == str(method)].values)
    else:
        #get_genre_scripts()
        #return(text['transcript name'][text['category'] == str(method)].values)
# Out:
#   Input In [33]
#     else:
#     ^
# IndentationError: expected an indented block

# %%
search()

# %%
###this function returns based on choice the full results or search for a specific result in the data frame###

# def decision(choice):
#     if choice in 'table':
#         return results
#     else:
#         search()

# %%
### this function propmtis you to choose the full results or search for a specific result in the data frame###

# def start():
#     print('this is the transcript analyzer...', 'press enter to continue')
#     input()
#     print('enter table to get the results or enter search to find specific results')
#     choices = input()
#     decision(choices)

# %%
# start()
